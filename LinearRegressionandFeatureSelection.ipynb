# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Data/Real-Data/Real_Combine.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0  13.2  18.2  9.2  1021.0  92.0  0.8  7.6  11.1  255.875000
# 1  11.1  18.3  5.0  1020.2  80.0  1.1  8.0  14.8  217.083333
# 2  12.7  19.8  5.2  1017.9  78.0  1.3  5.4  14.8  229.166667
# 3  11.9  20.7  4.4  1017.9  78.0  0.8  1.9   7.6  264.916667
# 4  11.7  20.7  6.5  1017.3  89.0  0.3  0.9   7.6  404.500000

# %% [markdown]
# # Feature Engineering

# %%
#using seaborn for visualizing to see if their are any null values
#it uses colour to represent the same
#Purple represents no null values
#to the extreme we have yellow color which should the presence of null values
#From the below picture we can see that their is a yellow colour which shows the presence of null values.

sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
#using pandas dataframe to check for null values.
#By looking at the result w can see that the last value is True,which mean it has no value


df.isnull()
# Out:
#          T     TM     Tm    SLP      H     VV      V     VM  PM 2.5
# 0    False  False  False  False  False  False  False  False   False
# 1    False  False  False  False  False  False  False  False   False
# 2    False  False  False  False  False  False  False  False   False
# 3    False  False  False  False  False  False  False  False   False
# 4    False  False  False  False  False  False  False  False   False
# 5    False  False  False  False  False  False  False  False   False
# 6    False  False  False  False  False  False  False  False   False
# 7    False  False  False  False  False  False  False  False   False
# 8    False  False  False  False  False  False  False  False   False
# 9    False  False  False  False  False  False  False  False   False
# 10   False  False  False  False  False  False  False  False   False
# 11   False  False  False  False  False  False  False  False   False
# 12   False  False  False  False  False  False  False  False   False
# ...

# %%
#Dropping the values which are null.


df=df.dropna()

# %%
#Again using heatmap in seaborn to check if the null value is dropped.
#cbar is giving us the density color and it shows that their is no  presence of null values.


sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# if its a classification problem,then we have to handle the imbalanced datasets.
# If any categorical values,then we have to convert that into integer value.
# But by analysis of ,the data we dont have to worry about the above two steps.

# %%
#Dependent feature:PM2.5 which is the last feature in our dataset

X=df.iloc[:,:-1]#Independent feature
y=df.iloc[:,-1]#Dependent feature

# %% [markdown]
# # Feature Selection

# %%
#Pairplots-seaborn,correlations-pandas,heatmaps-seaborn,ExtraTreeRegressors-sklearn  play a important role in feature selection.


#Feature selection will help us determine  how relevant the feature is towards the output variable.

# %%
sns.pairplot(df)

#The below pairplot using seaborn library  shows the relationshiip between 2 features usind 2-Dimentional diagrams.
#We can see a correlation between independent features like T,TM,Tm,SLP.
#However let us focus on dependent feature PM2.5 with respect to independent features which is displayed in the last row.

#Analysis:
#We can see no pattern.The points are scattered.
#If we apply Linear regression,the model may not be a good fit.

# %%
df.corr()

#The above pairplot in the form of correlation.
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.963143  0.955880 -0.882167 -0.502654  0.646224  0.322709
# TM      0.963143  1.000000  0.889228 -0.825320 -0.585589  0.616183  0.299037
# Tm      0.955880  0.889228  1.000000 -0.911344 -0.287675  0.565569  0.315883
# SLP    -0.882167 -0.825320 -0.911344  1.000000  0.244660 -0.512127 -0.331384
# H      -0.502654 -0.585589 -0.287675  0.244660  1.000000 -0.496726 -0.349278
# VV      0.646224  0.616183  0.565569 -0.512127 -0.496726  1.000000  0.354930
# V       0.322709  0.299037  0.315883 -0.331384 -0.349278  0.354930  1.000000
# VM      0.299148  0.308392  0.263955 -0.285960 -0.386286  0.330014  0.800897
# PM 2.5 -0.637122 -0.570782 -0.666536  0.611618  0.175765 -0.583777 -0.292566
#
#               VM    PM 2.5
# T       0.299148 -0.637122
# TM      0.308392 -0.570782
# Tm      0.263955 -0.666536
# SLP    -0.285960  0.611618
# H      -0.386286  0.175765
# VV      0.330014 -0.583777
# ...

# %%
# using heatmaps in seaborn library to see the relationship between the features.
#Similar to the pearson correlation and the pairplots used above.


import seaborn as sns
import matplotlib.pyplot as plt
#corrmat=df.corr()
#correlation_features=corrmat.index()
plt.figure(figsize=(20,20))

h=sns.heatmap(df.corr(),annot=True,cmap="RdYlGn")

# %%
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# C:\Users\K T KUMAR\Anaconda33\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#                     max_features='auto', max_leaf_nodes=None,
#                     min_impurity_decrease=0.0, min_impurity_split=None,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#                     oob_score=False, random_state=None, verbose=0,
#                     warm_start=False)

# %%
print(model.feature_importances_)
X.head()
# Out:
# [0.18239137 0.08949166 0.12604768 0.22570352 0.08559456 0.17775976
#  0.05803581 0.05497565]
#       T    TM   Tm     SLP     H   VV    V    VM
# 0  13.2  18.2  9.2  1021.0  92.0  0.8  7.6  11.1
# 1  11.1  18.3  5.0  1020.2  80.0  1.1  8.0  14.8
# 2  12.7  19.8  5.2  1017.9  78.0  1.3  5.4  14.8
# 3  11.9  20.7  4.4  1017.9  78.0  0.8  1.9   7.6
# 4  11.7  20.7  6.5  1017.3  89.0  0.3  0.9   7.6

# %%
#plot graph of feature importances for better visualization

feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances.plot(kind='barh')
plt.show()

# %%
feature_importances.nlargest(5).plot(title='Top 5 important features relavant towards the output variable',kind='barh')

# %% [markdown]
# # Linear Regression

# %%
sns.distplot(y)

#We can see that the dependent feature PM2.5 is right skewed .
#It is not normally distributed

# %%
#Let us split out train and test sets

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# # Training my model

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.coef_
# Out:
# array([-1.74236706e-02,  1.39660949e+00, -5.84111330e+00,  6.68657500e-01,
#        -7.12134191e-01, -3.92139247e+01, -8.57748526e-01, -5.61219290e-01])

# %%
coeff=pd.DataFrame(regressor.coef_,X.columns,columns=['Coefficient'])
coeff
# Out:
#      Coefficient
# T      -0.017424
# TM      1.396609
# Tm     -5.841113
# SLP     0.668657
# H      -0.712134
# VV    -39.213925
# V      -0.857749
# VM     -0.561219

# %% [markdown]
# coeeficient values are nothing but the slope values (y=mx+c)
# y is PM2.5
#
# Interpretation:
#     Considering all the other independent features fixed,unit increase in T will have a decrease of 0.017 in PM2.5
#     Considering all the other independent features fixed,unit increase in TM will have a increase of 1.39 in PM2.5
#     Considering all the other independent features fixed,unit increase in Tm will have a decrease of 5.84 in PM2.5
#     Considering all the other independent features fixed,unit increase in SLP will have a increase of 0.66 in PM2.5
#     Considering all the other independent features fixed,unit increase in H will have a decrease of 0.712 in PM2.5
#     Considering all the other independent features fixed,unit increase in VV will have a decrease of 39.21 in PM2.5
#     Considering all the other independent features fixed,unit increase in v will have a decrease of 0.85 in PM2.5
#     Considering all the other independent features fixed,unit increase in VM will have a decrease of 0.56 in PM2.5

# %%
regressor.intercept_
# Out:
# -353.93317455696933

# %%
Interpretation:
y=mx+c
c is the intercept
considering all the independent features as zero the value of intercept will be -353
so PM2.5=-353.93

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train,y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.5487825487959246

# %% [markdown]
# Error rate of the best fit line is determined by the R square value .
# If the value is close to 1 then it will be the best fit line
# If not we have to try other techniques to determine the best fit model for the given problem statement

# %%
X_train.shape
# Out:
# (632, 8)

# %%
y_train.shape
# Out:
# (632,)

# %%
X_test.shape
# Out:
# (272, 8)

# %%
y_test.shape
# Out:
# (272,)

# %%
X.shape
# Out:
# (904, 8)

# %%
y.shape
# Out:
# (904,)

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train,y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.5487825487959246

# %% [markdown]
# R^2 value for train data set is 54%.It should be more closer to one to say that the modelis a good fit

# %%
print("Coefficient of determination R^2 <-- on test set: {}".format(regressor.score(X_test,y_test)))
# Out:
# Coefficient of determination R^2 <-- on test set: 0.47172466066254226

# %% [markdown]
# R^2 value for test data set is 47%.It should be more closer to one to say that the model is a good fit.
#
#
# We can try other techniques to check for a better model fit.

# %% [markdown]
# Challenge faced:
#     Initially the regressor fir was done for X,y insted of X_train and y_train which lead me to the error:
#         "ValueError: Found input variables with inconsistent numbers of samples:"
#
# Solution:
#     Ensure the shape of X and y are equal to determine the R^2 value.

# %% [markdown]
# Cross value score on Linear Regression computes the R^2 value for k fold.
#
# In the above dataset we have 904 records.
#
# If we assign the attribute cv=4
#
# 904 records will be divided by 4
#
# The first 226 will be train data set and the rest will test dataset
#
# next
#
# The second 226 will be train data set and the rest will test dataset and it goes on till 4 times.

# %%
from sklearn.model_selection import cross_val_score

score=cross_val_score(regressor,X,y,cv=4)

score
# Out:
# array([0.48800044, 0.47981263, 0.43384847, 0.47446618])

# %%
score.mean()
# Out:
# 0.4690319289281746

# %% [markdown]
# # Model evaluation:
# We can predict the class for new data instances using our finalized  model in scikit-learn using the predict() function.

# %% [markdown]
# # Predicting Test Data

# %%
prediction=regressor.predict(X_test)

# %%
sns.distplot(y_test-prediction)

# %% [markdown]
# Interpretation:The graph is almost a guassian distribution curve.It looks close to like a bell curve.
#
# Residuals
#
# Explore the residuals to make sure everything was okay with our data.
#
# Since it is almost normally distributed we can say that it is a good model.

# %%
#Create a scatterplot of the real test values versus the predicted values.

plt.scatter(y_test,prediction)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
plt.show()

# %% [markdown]
# Interpretation:We can see a pattern which is good.

# %% [markdown]
# # Regression evaluation metrics:
#     Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 43.352636982768054
# MSE: 3452.3009842363704
# RMSE: 58.75628463608272

# %% [markdown]
# # Save the Model:
#
# Save the model using pickle Once saved, you can load the model any time and use it to make predictions

# %%
import pickle

# %%
# open a file, where you want to store the data

file=open('regression_model.pkl','wb')


pickle.dump(regressor,file)

# %% [markdown]
# We can see the pickle file creted which will be used in the deployement.
# It is kind of like a black box file which we cannot open and see.
# But if we given the input it will give the output .
# In our case it is the dependent variable PM2.5
